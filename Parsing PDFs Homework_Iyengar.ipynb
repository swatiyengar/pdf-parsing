# %% [markdown]
# # Parsing PDFs Homework
#
# With the power of pdfminer, pytesseract, Camelot, and Tika, let's analyze some documents!
#
# > If at any point you think, **"I'm close enough, I'd just edit the rest of it in Excel"**: that's fine! Just make a note of it.
#
# ## A trick to use again and again
#
# ### Approach 1
#
# Before we get started: when you want to take the first row of your data and set it as the header, use this trick.

# %%
#import libraries
import pandas as pd

# %%
df = pd.DataFrame([
    [ 'fruit name', 'likes' ],
    [ 'apple', 15 ],
    [ 'carrot', 3 ],
    [ 'sweet potato', 45 ],
    [ 'peach', 12 ],
])

# %%
df
# Out:
#               0      1
# 0    fruit name  likes
# 1         apple     15
# 2        carrot      3
# 3  sweet potato     45
# 4         peach     12

# %%
# Set the first column as the columns
df.columns = df.loc[0]

# %%
# Drop the first row
df = df.drop(0)

# %%
df
# Out:
# 0    fruit name likes
# 1         apple    15
# 2        carrot     3
# 3  sweet potato    45
# 4         peach    12

# %% [markdown]
# 🚀 Done!
#
# ### Approach 2
#
# Another alternative is to use `.rename` on your columns and just filter out the columns you aren't interested in. This can be useful if the column name shows up multiple times in your data for some reason or another.

# %%
# Starting with the same-ish data...
df = pd.DataFrame([
    [ 'fruit name', 'likes' ],
    [ 'apple', 15 ],
    [ 'carrot', 3 ],
    [ 'fruit name', 'likes' ],
    [ 'sweet potato', 45 ],
    [ 'peach', 12 ],
])

# %%
df
# Out:
#               0      1
# 0    fruit name  likes
# 1         apple     15
# 2        carrot      3
# 3    fruit name  likes
# 4  sweet potato     45
# 5         peach     12

# %%
df = df.rename(columns={
    0: 'fruit name',
    1: 'likes'
})

# %%
df = df[df['fruit name'] != 'fruit name']

# %%
df
# Out:
#      fruit name likes
# 1         apple    15
# 2        carrot     3
# 4  sweet potato    45
# 5         peach    12

# %% [markdown]
# 🚀 Done!
#
# ### Useful tips about coordinates
#
# If you want to grab only a section of the page [Kull](https://jsoma.github.io/kull/#/) might be helpful in finding the coordinates.
#
# > **Alternatively** run `%matplotlib notebook` in a cell. Afterwards, every time you use something like `camelot.plot(tables[0]).show()` it will get you nice zoomable, hoverable versions that include `x` and `y` coordinates as you move your mouse.
#
# Coordinates are given as `"left_x,top_y,right_x,bottom_y"` with `(0,0)` being in the bottom left-hand corner.
#
# Note that all coordinates are strings, for some reason. It won't be `[1, 2, 3, 4]` it will be `['1,2,3,4']`
#
# # The homework
#
# This is **mostly Camelot work**, because I don't really have any good image-based PDFs to stretch your wings on tesseract. If you know of any, let me know and I can put together another couple exercises.
#
# ## Prison Inmates
#
# Working from [InmateList.pdf](InmateList.pdf), save a CSV file that includes every inmate.
#
# * Make sure your rows are *all data*, and you don't have any people named "Inmate Name."

# %%
import camelot

# %%
inmate = camelot.read_pdf('sources/InmateList.pdf', flavor = 'stream', pages = '1-end', table_areas = ["17,732,358,105"])

# %%
dfs = [table.df for table in inmate]

# %%
inmate_df = pd.concat(dfs, ignore_index = True)

# %%
inmate_df = inmate_df.rename(columns={
    0: 'ICN #',
    1: 'Inmate Name',
    2: 'Facility',
    3: 'Booking Date'
})

# %%
inmate_df = inmate_df[(inmate_df['ICN #'] != 'ICN #')]

# %%
inmate_df.to_csv("outputs/inmate_list.csv",index = False)

# %% [markdown]
# ## WHO resolutions
#
# Using [A74_R13-en.pdf](A74_R13-en.pdf), what ten member countries are given the highest assessments?
#
# * You might need to have two separate queries, and combine the results: that last page is pretty awful!
# * Always rename your columns
# * Double-check that your sorting looks right......
# * You can still get the answer even without perfectly clean data

# %%
who = camelot.read_pdf('sources/A74_R13-en.pdf', flavor = 'stream', pages = '1-5')
who_6 = camelot.read_pdf('sources/A74_R13-en.pdf', flavor = 'stream', pages = '6', table_areas = ["75,744,388,644"])

# %%
who_dfs = [table.df for table in who]

# %%
who_df = pd.concat(who_dfs, ignore_index = True)

# %%
who_df
# Out:
#                                       0              1
# 0                           Members and      WHO scale
# 1                     Associate Members  for 2022–2023
# 2                                                    %
# 3                           Afghanistan         0.0070
# 4                               Albania         0.0080
# ..                                  ...            ...
# 210                          Uzbekistan         0.0320
# 211                             Vanuatu         0.0010
# 212  Venezuela (Bolivarian Republic of)         0.7280
# 213                            Viet Nam         0.0770
# 214                               Yemen         0.0100
#
# [215 rows x 2 columns]

# %%
who_df = who_df.append(who_6[0].df)

# %%
who_df.head()
# Out:
#                    0              1
# 0        Members and      WHO scale
# 1  Associate Members  for 2022–2023
# 2                                 %
# 3        Afghanistan         0.0070
# 4            Albania         0.0080

# %%
who_df = who_df[(who_df[0] != 'Members and') & (who_df[0] != 'Associate Members') & (who_df[1] != 'WHO scale') & (who_df[1] != '%') & (who_df[1] != 'for 2022-2023')& (who_df[0] != 'TOTAL')]

# %%
who_df = who_df.rename(columns = {
    0 : 'member_state',
    1 : 'assessment'
}).reset_index(drop = True)

# %%
who_df.assessment = pd.to_numeric(who_df.assessment)

# %%
who_df.sort_values(by = 'assessment', ascending=False).head(10)
# Out:
#                  member_state  assessment
# 193  United States of America     22.0000
# 35                      China     12.0058
# 88                      Japan      8.5645
# 68                    Germany      6.0904
# 191          Northern Ireland      4.5673
# 64                     France      4.4273
# 86                      Italy      3.3072
# 23                     Brazil      2.9482
# 31                     Canada      2.7342
# 148        Russian Federation      2.4052

# %% [markdown]
# ## The Avengers
#
# Using [THE_AVENGERS.pdf](THE_AVENGERS.pdf), approximately how many lines does Captain America have as compared to Thor and Iron Man?
#
# * Character names only: we're only counting `IRON MAN` as Iron Man, not `TONY`.
# * Your new best friend might be `\n`
# * Look up `.count` for strings

# %%
from pdfminer.high_level import extract_text

# %%
avengers = extract_text('sources/THE_AVENGERS.pdf')

# %%
avengers
# Out:
# 'Marvel’s THE AVENGERS\n\nWritten By\n\nJoss Whedon\n\nStory By\nZak Penn and Joss Whedon\n\nBased on the characters appearing in the comic books\nPublished by MARVEL Comics\n\nTranscribed to PDF using:\nCeltx Studio | 2012\n\nComposed In Celtx Studio\nWith the help of\nSiOmniaFicta’s Script\non fanfiction.net\n\nENTERTAINMENT PURPOSES ONLY\n\n\x0c1\n\n2\n\n3\n\n1\n\nEXT. UNKNOWN AREA OF SPACE\n\nSpace, a floating staircase among the rocks...THE OTHER\nspeaks to a DISEMBODIED FIGURE in a chair.\n\nTHE OTHER hands LOKI a scepter with a glowing blue gem...\n\nTHE OTHER (V.O)\n\nThe Tesseract has awakened. It is\non a little world, a human world.\nThey would wield its power.\n\nTHE OTHER (V.O)\nBut our ally knows its workings as\nthey never will. He is ready to\nlead. And our force...\n\nTHE OTHER (V.O)\n\n...our Chitauri, will follow. The\nworld will be his...the universe,\nyours. And the humans, what can\nthey do but burn?\n\nThe CHITAURI put on their face mask and get ready.\n\nA 3d model of the Tesseract, we move inside it slowly\n\nEXT. MOUNTAIN RANGE - EARLY NIGHT\n\nA helicopter SPEEDS over this mountain at high-speed. The\nCAMERA pans up over the mountain and we see...\n\nEXT. SHIELD/NASA FACILITY - CONTINUOUS\n\n2\n\n3\n\nThis base is grand beyond belief. There is a frantic\nevacuation in progress. AGENTS, SCIENTISTS, and PERSONNEL\nrush around the base frantically.\n\nINTERCOM VOICE\nAll personnel, evacuation order has\nbeen confirmed. Proceed to your\ndesignated vehicles...\n\nA man flushes people by. The sign on the building reads:\n\nJOINT DARK ENERGY MISSION; WESTERN DIVISION; PROJECT\nPEGASUS, NASA SPACE RADIATION FACILITY, S.H.I.E.L.D\nACCELERATOR TEST FACILITY\n\n...for all campus evacuation.\n\nINTERCOM VOICE\n\nSecurity Guards direct traffic. SHIELD agents assist people,\nsome stuff the trunks of their cars and leave the campus.\n\n(CONTINUED)\n\n\x0cCONTINUED: (2)\n\n2.\n\nINTERCOM VOICE (CONT’D)\n\nThis is not a drill. Emergency\npersonnel proceed to your\ndesignated vehicles for all campus\nevacuation.\n\nThe helicopter slows above a-\n\n4\n\nEXT. LANDING PAD, SHIELD/NASA FACILITY - CONTINUOUS\n\n4\n\nThere is a man in suit waiting. This is AGENT PHIL COULSON.\n\nON THE CHOPPER: The door slides open. Out comes a female,\nthis is AGENT MARIA HILL. Following behind her is NICK FURY.\n\nFury and Hill walk over to Coulson.\n\nFURY\nHow bad is it?\n\nAGENT COULSON\nThat’s the problem, sir. We don’t\nknow.\n\n5\n\n6\n\nINT. ELEVATOR SHAFT - MOMENTS LATER (EARLY NIGHT)\n\nAn elevator rushes down. It’s going fast.\n\nDoctor Selvig read an...\n\nAGENT COULSON (V.O)\n\nINT. LOWER LEVEL - CONTINUOUS\n\n5\n\n6\n\nCoulson, Fury, and Hill make their way through the crowds of\nevacuating personnel.\n\nAGENT COULSON\n...energy surge from the Tesseract\nfour hours ago.\n\nFURY\n\nNASA didn’t authorize Selvig could\ngo to test B.\n\nAGENT COULSON\n\nHe wasn’t testing it. He wasn’t\neven in the room. Spontaneous\nevent.\n\nMARIA HILL\n\nIt just turned itself on?\n\n(CONTINUED)\n\n\x0cCONTINUED: (2)\n\n3.\n\nFury and Hill continue on as Coulson turns around and heads\nthe other way.\n\n7\n\nINT. STAIRCASE - MOMENTS LATER (EARLY NIGHT)\n\n7\n\nFury and Hill make their way down to the lower levels.\n\nWhere are the energy levels now?\n\nAGENT COULSON\n\nClimbing. When Selvig couldn’t shut\nit down we ordered evac.\n\nFURY\n\nFURY\n\nHow long to get everyone out?\n\nAGENT COULSON\nCampus should be clear in the next\nhalf hour.\n\nDo better.\n\nFURY\n\nMARIA HILL\nSir, evacuation may be futile.\n\nFURY\n\nWe should tell them to go back to\nsleep?\n\nMARIA HILL\n\nIf we can’t control the Tesseract’s\nenergy there may not be a minimum\nsafe distance.\n\nI need you to make sure the Phase\nTwo prototypes are shipped out.\n\nMARIA HILL\nSir, is that really a priority\nright now?\n\nFURY\n\nFURY\n\nUntil such time as the world ends\nwe will act as though it intends to\nspin on. Clear out the tech below.\nEvery piece of Phase Two on a tru ...

# %%
cap_lines = avengers.count("\nCAPTAIN AMERICA\n")
cap_lines
# Out:
# 35

# %%
thor_lines = avengers.count("\nTHOR\n")
thor_lines
# Out:
# 47

# %%
ironman_lines = avengers.count("\nIRON MAN\n")
ironman_lines
# Out:
# 19

# %%
f"Captain America has {cap_lines-ironman_lines} more lines than Iron Man, but {abs(cap_lines-thor_lines)} fewer lines than Thor."
# Out:
# 'Captain America has 16 more lines than Iron Man, but 12 fewer lines than Thor.'

# %%
#to count words after: capture the lines after captain america 
#regex that extracts this part of the text

# %% [markdown]
# ## COVID data
#
# Using [covidweekly2721.pdf](covidweekly2721.pdf), what's the total number of tests performed in Minnesota? Use the Laboratory Test Rates by County of Residence chart.
#
# * You COULD pull both tables separately OR you could pull them both at once and split them in pandas.
# * Remember you can do things like `df[['name','age']]` to ask for multiple columns

# %%
covid = camelot.read_pdf('sources/covidweekly2721.pdf', flavor = 'lattice', pages = '6')

# %%
covid = covid[1].df

# %%
covid.columns = covid.loc[0]

# %%
covid = covid.drop(0)

# %%
covid_1 = covid.iloc[:,[0,1,2]]
covid_2 = covid.iloc[:,[3,4,5]]

# %%
covid = covid_1.append(covid_2).reset_index(drop = True)

# %%
covid.loc[covid['County']=='Benton'] = [['Benton', '77,865', '19,574']]

# %%
covid
# Out:
# 0            County Number of Tests Cumulative Rate
# 0            Aitkin          19,204          12,128
# 1             Anoka         545,958          15,714
# 2            Becker          59,238          17,540
# 3          Beltrami          60,345          13,085
# 4            Benton          77,865          19,574
# ..              ...             ...             ...
# 83           Wilkin           7,973          12,570
# 84           Winona         106,625          20,970
# 85           Wright         194,085          14,621
# 86  Yellow Medicine          19,972          20,239
# 87  Unknown/missing         423,136
#
# [88 rows x 3 columns]

# %% [markdown]
# ## Theme Parks
#
# Using [2019-Theme-Index-web-1.pdf](2019-Theme-Index-web-1.pdf), save a CSV of the top 10 theme park groups worldwide.
#
# * You can clean the results or you can restrict the area the table is pulled from, up to you

# %%
themepark = camelot.read_pdf('sources/2019-Theme-Index-web-1.pdf', pages = '11', flavor = 'stream', table_areas = ["12,469,400,291"])

# %%
themepark = themepark[0].df

# %%
themepark = themepark.rename(columns = {
    0: 'rank',
    1: 'group_name',
    2: '%_change',
    3: 'attendance_2019',
    4: 'attendance_2018'
})

# %%
themepark.to_csv('outputs/top10themeparkgroups.csv', index = False)

# %% [markdown]
# ## Hunting licenses
#
# Using [US_Fish_and_Wildlife_Service_2021.pdf](US_Fish_and_Wildlife_Service_2021.pdf) and [a CSV of state populations](http://goodcsv.com/geography/us-states-territories/), find the states with the highest per-capita hunting license holders.

# %%
hunt = camelot.read_pdf('sources/US_Fish_and_Wildlife_Service_2021.pdf', pages = '1', flavor = 'lattice', strip_text = " .\n,")

# %%
hunt = hunt[0].df

# %%
hunt = hunt.rename(columns = {
    0 : 'state',
    1 : 'paid_hunt_lholders',
    2 : 'resident_hunt_ltps',
    3 : 'non-res_hunt_ltps',
    4 : 'total_hunt_ltps',
    5 : 'cost-resident_hunt_ltps',
    6 : 'cost-non-res_hunt_ltps',
    7 : 'gross_cost_hunt_licenses'
}).drop([0,57])

# %%
hunt
# Out:
#    state paid_hunt_lholders resident_hunt_ltps non-res_hunt_ltps  \
# 1     AK              93559             423501             59235
# 2     AL             452400             601683             45397
# 3     AR             343300             349098            150728
# 4     AS                  0                  0                 0
# 5     AZ             302383             464607             88708
# 6     CA             262009             949540             25535
# 7     CO             296609             481253            120954
# 8     CT              32052             101377              4543
# 9     DC                  0                  0                 0
# 10    DE              15619              45997              6044
# 11    FL             191501             275295             20104
# 12    GA             724269            1278512            156423
# 13    GU                543               1334                 0
# 14    HI              10608              10697              1274
# 15    IA             214398             567033             70562
# 16    ID             275244            1412039            248610
# 17    IL             293617            1286280             81944
# 18    IN             250481             337728             21356
# 19    KS             264331             286196            174334
# 20    KY             319690             432216            114649
# 21    LA             424918             522414             52724
# 22    MA              55139             239101             17849
# 23    MD             116702             272730             65204
# 24    ME             201370             193326             33866
# 25    MI             642242            2027911             56781
# 26    MN             545300            1287146             44750
# 27    MO             472993            1718224             93646
# 28    MP                 23                 23                 0
# 29    MS             271281             292528             84168
# 30    MT             222309             853341            186315
# 31    NC             609131             280656             26404
# 32    ND             135724             375250            126916
# 33    NE             180932             299496             93317
# 34    NH              55562             129474             20511
# 35    NJ              68767             281220            121963
# 36    NM             110874             287829            112877
# 37    NV              89603              97387             28489
# 38    NY             550868            1343275             49018
# 39    OH             346220             770492             99530
# 40    OK             512724             387930             27899
# 41    OR             328323            1250170             68043
# 42    PA             945731            2299595            109096
# 43    PR               7362               2151                11
# 44    RI               7514              49019              4705
# 45    SC             208843             893226            107735
# 46    SD             213786             241059            115902
# 47    TN             694458             722305             66774
# 48    TX            1094753            1617322             86692
# 49    UT             250565             405303             50260
# 50    VA             254517             776242             42686
# 51    VI                  0                  0                 0
# 52    VT              62237             166813             16988
# 53    WA             171940             688501             13365
# 54    WI             666670            3965367            236639
# 55    WV             205447             484447            143966
# 56    WY             135228             186849             82865
#
#    total_hunt_ltps cost-resident_hunt_ltps cost-non-res_hunt_ltps  \
# 1           482736                $4859356               $9046715
# 2           647080                $9700295               $6715734
# 3           499826                $7851601              $11271653
# 4                0                      $0                     $0
# 5           553315               $13931397               $5968169
# 6           975075               $20270941               $1114625
# 7           602207               $13270492              $49732815
# 8           105920                $1855046                $372108
# 9                0                      $0                     $0
# 10           52041                 $899857                $499867
# 11          295399                $5745815               $1185179
# 12         1434935                $9182934               $9505429
# 13            1334                  $15995                     $0
# 14           11971                 $424453                $133770
# 15          637595               $12654471               $5250727
# 16         1660649               $11465795              $18704191
# 17         1368224               $15058155              $14764600
# 18          359084                $8656243               $2450035
# 19          460530                $7325503              $18428588
# 20          546865               $12223653               $8728198
# 21          575138                $7636981               $1958068
# 22          256950                $1909776                $445310
# 23          337934                $3237325               $3110066
# 24          227192                $4443522               $3143929
# 25         2084692               $30975103               $4192335
# 26         1331896               $28262127               $3899420
# 27         1811870               $12049038               $9941978
# 28              23                    $230                     $0
# 29          376696                $4729196               $7796435
# 30         1039656               $10966890              $26951488
# 31          307060                $8274234               $2264888
# 32          502166                $4680314               $6094905
# 33          392813                $8366685               $7558178
# 34          149985                $3071480               $1432078
# 35          403183                $6328826               $1152802
# 36          400706                $5164543              $11689723
# 37          125876                $3634268               $3475115
# 38         1392293               $19993113               $4166190
# 39          870022               $14636310               $8145996
# 40          415829                $5313277               $4704096
# 41         1318213               $22316871               $6004417
# 42         2408691               $31435305               $6418857
# 43            2162                  $84926                   $760
# 44           53724                 $607820                $133965
# 45         1000961                $4795967               $5180858
# 46          356961                $7425329              $13522167
# 47          789079               $11501652               $4415002
# 48         1704014               $34381172              $12097724
# 49          455563               $12799520               $6708584
# 50          818928               $18589392               $3831438
# 51               0                      $0                     $0
# 52          183801                $3083660               $1005616
# 53          701866               $16004985               $1063616
# 54         4202006               $28526992               $7884672
# 55          628413                $3800948               $4881189
# 56          269714               $11254147              $23660065
#
#    gross_cost_hunt_licenses
# 1                 $13906071
# 2                 $16416029
# 3                 $19123254
# 4                        $0
# 5                 $19899566
# 6                 $21385566
# 7                 $63003307
# 8                  $2227154
# 9                        $0
# 10                 $1399724
# 11                 $6930994
# 12                $18688363
# 13                   $15995
# 14                  $558223
# 15                $17905198
# 16                $30169986
# 17                $29822755
# 18                $11106278
# 19                $25754091
# 20                $20951851
# 21                 $9595049
# 22                 $2355086
# 23                 $6347391
# 24                 $7587451
# 25                $35167438
# 26                $32161547
# 27                $21991016
# 28                     $230
# 29                $12525631
# 30                $37918378
# 31                $10539122
# 32                $10775219
# 33                $15924863
# 34                 $4503558
# 35                 $7481628
# 36                $16854266
# 37                 $7109383
# 38                $24159303
# 39                $22782306
# 40                $10017373
# 41                $28321288
# 42                $37854162
# 43                   $85686
# 44                  $741785
# 45                 $9976825
# 46                $20947496
# 47                $15916654
# 48                $46478896
# 49                $19508104
# 50                $22420830
# 51                       $0
# 52                 $4089276
# 53                $17068601
# 54                $36411664
# 55                 $8682137
# 56                $34914212

# %%
hunt['total_license_percap'] = pd.to_numeric(hunt['total_hunt_ltps']) / pd.to_numeric(hunt['paid_hunt_lholders'])

# %%
hunt.sort_values(by = 'total_license_percap', ascending = False).head(5)
# Out:
#    state paid_hunt_lholders resident_hunt_ltps non-res_hunt_ltps  \
# 44    RI               7514              49019              4705
# 54    WI             666670            3965367            236639
# 16    ID             275244            1412039            248610
# 35    NJ              68767             281220            121963
# 1     AK              93559             423501             59235
#
#    total_hunt_ltps cost-resident_hunt_ltps cost-non-res_hunt_ltps  \
# 44           53724                 $607820                $133965
# 54         4202006               $28526992               $7884672
# 16         1660649               $11465795              $18704191
# 35          403183                $6328826               $1152802
# 1           482736                $4859356               $9046715
#
#    gross_cost_hunt_licenses  total_license_percap
# 44                  $741785              7.149854
# 54                $36411664              6.302977
# 16                $30169986              6.033370
# 35                 $7481628              5.863030
# 1                 $13906071              5.159696
